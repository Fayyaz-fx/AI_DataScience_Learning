# %% [markdown]
# # Week 01 - Lab 02
# Today  we will with lots of models! This is a way to get comfortable with APIs'.

# %%
# Start with imports
import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
openai_api_key = os.getenv("OPENAI_API_KEY")
ollama_api_key = os.getenv("OLLAMA_API_KEY")
gemini_api_key = os.getenv("GOOGLE_API_KEY").strip()

if openai_api_key:
    print(f"OpenAI API key exists and begins with {openai_api_key[:10]}")
else:
    print("OpenAI API Key not set")
if ollama_api_key:
    print(f"Ollama API key exists and begins with {ollama_api_key[:5]}")

else:
    print("Ollama API Key not set")

if gemini_api_key:
    print(f"Goodle API key exists and begins with {gemini_api_key[:5]}")

else:
    print("Google API Key not set")
# Out:
# OpenAI API key exists and begins with sk-proj-3Z
# Ollama API key exists and begins with ollam
# Google API Key not set

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanaion. "
messages = [{
    'role': 'user',
    'content': request
}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanaion. '}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model = 'gpt-4o-mini',
    messages = messages

)

question = response.choices[0].message.content

print(question)
# Out:
# How would you reconcile the ethical implications of artificial intelligence in decision-making processes with the necessity for transparency and accountability in those systems, especially in high-stakes environments like healthcare or criminal justice?

# %%
competitors = []
answers = []
messages = [{
    'role': 'user',
    'content': question
}]

# %%
model_name = 'gpt-4o-mini'
response = openai.chat.completions.create(model = model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Reconciling the ethical implications of artificial intelligence (AI) in decision-making processes with the necessity for transparency and accountability requires a multi-faceted approach, particularly in high-stakes domains such as healthcare and criminal justice. Here are some key considerations and strategies to achieve this balance:
#
# 1. **Establish Clear Ethical Guidelines**:
#    - Develop ethical frameworks that prioritize fairness, justice, and the well-being of individuals affected by AI decisions. These guidelines should be informed by diverse stakeholders, including ethicists, legal experts, and representatives from impacted communities.
#
# 2. **Enhance Transparency**:
#    - Ensure that AI systems are designed with transparency in mind. This includes making algorithms interpretable and understandable for both users and those affected by decisions. Tools like explainable AI (XAI) can aid in elucidating how decisions are made.
#    - Document the data sources, modeling choices, and decision-making processes involved in AI systems. Stakeholders should have access to information regarding the system’s limitations and potential biases.
#
# 3. **Implement Accountability Mechanisms**:
#    - Assign clear accountability for AI-driven decisions. This includes establishing protocols for who is responsible when an AI decision leads to negative outcomes and ensuring that human oversight remains integral to the process.
#    - Create channels for recourse, where individuals can challenge or appeal AI-generated decisions, thereby providing a safety net for potentially harmful outcomes.
#
# 4. **Engage in Stakeholder Participation**:
#    - Involve a diverse set of stakeholders in the design, implementation, and evaluation of AI systems. This includes patients, families, community leaders, and advocacy groups, especially in healthcare, to ensure that multiple perspectives are taken into account.
#    - Foster ongoing public dialogue about the ethical use of AI, enabling communities to voice concerns and shape the development of AI technologies.
#
# 5. **Prioritize Data Governance**:
#    - Implement robust data governance frameworks to ensure that data used in AI systems is collected, stored, and utilized responsibly. This includes addressing issues of consent, data privacy, and protection against discrimination.
#    - Conduct regular audits of AI systems to assess and mitigate bias, ensuring that the algorithms do not perpetuate historical inequalities.
#
# 6. **Foster Interdisciplinary Collaboration**:
#    - Encourage cooperation among technologists, ethicists, legal experts, and industry practitioners to address the complexities of AI in decision-making. This interdisciplinary approach can provide holistic insights into the implications of AI technology.
#
# 7. **Develop Regulatory Standards**:
#    - Collaborate with policymakers to establish regulatory standards specifically designed for AI applications in critical sectors. These standards should include requirements for ethical considerations, transparency, and accountability.
#
# 8. **Promote Continuous Learning and Adaptation**:
#    - Recognize that AI technologies will evolve, and so will their ethical implications. Establish frameworks for continuous monitoring and re-evaluation of AI systems to adapt to new findings, societal changes, and stakeholder feedback.
#
# By integrating these strategies, it becomes possible to address the ethical implications associated with AI in decision-making while ensuring that transparency and accountability are maintained. This balanced approach not only enhances the trustworthiness of AI systems but also safeguards the rights and well-being of individuals within high-stakes environments.

# %%
ollama_base_url = "http://localhost:11434/v1"
ollama = OpenAI(base_url=ollama_base_url, api_key=ollama_api_key)

# %%
model_name = 'Gemma4:e4b'
respone = ollama.chat.completions.create(
    model = model_name,
    messages = messages
)

# %%
answer = response.choices[0].message.content
display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Approaching the ethical implications of deploying an AI system that enhances human cognitive abilities while potentially exacerbating existing social inequalities requires a multi-faceted strategy. Here’s a breakdown of the essential considerations:
#
# ### 1. **Identify Stakeholders and Their Perspectives**
#    - **Broad Stakeholder Engagement**: Engage diverse stakeholders, including marginalized communities, ethicists, educators, technologists, and policymakers. Understanding varied perspectives is crucial to identify who might benefit and who might be disadvantaged.
#    - **Equity Assessment**: Analyze how the technology will impact different socio-economic groups. Assess potential risks that could arise, particularly for those already at a disadvantage.
#
# ### 2. **Framework for Ethical Evaluation**
#    - **Principles of Justice**: Apply frameworks such as justice, fairness, and equity. Consider how benefits and burdens are distributed across different groups.
#    - **Informed Consent**: Ensure that users are fully informed about the potential impacts of the AI system. This includes benefits, risks, and the nuances of cognitive enhancement.
#
# ### 3. **Addressing Inequality**
#    - **Access and Affordability**: Evaluate how costs and access to the AI enhancements will be managed. Create strategies to make the technology available to underprivileged populations, potentially through subsidies or public programs.
#    - **Inclusion in Development**: Involve representatives from disadvantaged communities in the design and development process to ensure that their needs and concerns are prioritized.
#
# ### 4. **Mitigation Strategies**
#    - **Regulatory Oversight**: Advocate for regulations that govern the deployment of cognitive enhancement technologies, ensuring they are aligned with ethical standards and do not widen the gap of social inequalities.
#    - **Monitoring and Evaluation**: Establish ongoing assessment processes to monitor the impact of the AI on social inequality and adjust policies accordingly.
#
# ### 5. **Public Dialogue and Transparency**
#    - **Open Discourse**: Foster public discussion around the ethical usage of cognitive enhancement technologies. Transparent communication regarding the goals, limitations, and ethical considerations of the AI is vital.
#    - **Education and Literacy**: Promote basic digital and AI literacy to empower individuals to engage with AI technologies critically and constructively.
#
# ### 6. **Long-Term Considerations**
#    - **Sustainability of Impact**: Consider the long-term societal implications of cognitive enhancement. What happens if some groups are more empowered than others? How will this affect future generations?
#    - **Socio-cultural Impacts**: Investigate how enhanced cognitive abilities may influence societal norms, cultural values, and interpersonal relationships.
#
# ### 7. **Ethics in Research and Development**
#    - **Responsible Innovation**: Foster a culture of ethical responsibility within research and development teams. Encourage interdisciplinary collaboration to address ethical concerns proactively.
#    - **Scenario Planning**: Use scenario analysis to anticipate potential negative outcomes and develop strategies to address them before deployment.
#
# ### Conclusion
# Deploying an AI system that enhances cognitive abilities has transformative potential but also significant ethical challenges. By prioritizing equity, engaging diverse stakeholders, and implementing robust oversight and monitoring systems, we can navigate the complex landscape of cognitive enhancement in a way that seeks to benefit society as a whole, rather than exacerbate existing inequalities. Ultimately, ethical technology deployment requires a commitment to vigilance, inclusivity, and responsible stewardship.

# %%
gemini = OpenAI(
    api_key=google_api_key,
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(
    model = model_name,
    messages = messages
)
answer = response.choices[0].message.content
display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[18], line 7
#       3     base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
#       4 )
#       5 model_name = "gemini-2.5-flash"
#       6
# ----> 7 response = gemini.chat.completions.create(
#       8     model = model_name,
#       9     messages = messages
#      10 )
#
# File c:\AI_DataScience_Learning\AI_Engineer_Agentic_Track\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File c:\AI_DataScience_Learning\AI_Engineer_Agentic_Track\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1251, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1203 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1204 def create(
#    1205     self,
#    (...)   1248     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1249 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1250     validate_response_format(response_format)
# -> 1251     return self._post(
#    1252         "/chat/completions",
#    1253         body=maybe_transform(
#    1254             {
#    1255                 "messages": messages,
#    1256                 "model": model,
#    1257                 "audio": audio,
#    1258                 "frequency_penalty": frequency_penalty,
#    1259                 "function_call": function_call,
#    1260                 "functions": functions,
#    1261                 "logit_bias": logit_bias,
#    1262                 "logprobs": logprobs,
#    1263                 "max_completion_tokens": max_completion_tokens,
#    1264                 "max_tokens": max_tokens,
#    1265                 "metadata": metadata,
#    1266                 "modalities": modalities,
#    1267                 "moderation": moderation,
#    1268                 "n": n,
#    1269                 "parallel_tool_calls": parallel_tool_calls,
#    1270                 "prediction": prediction,
#    1271                 "presence_penalty": presence_penalty,
#    1272                 "prompt_cache_key": prompt_cache_key,
#    1273                 "prompt_cache_retention": prompt_cache_retention,
#    1274                 "reasoning_effort": reasoning_effort,
#    1275                 "response_format": response_format,
#    1276                 "safety_identifier": safety_identifier,
#    1277                 "seed": seed,
#    1278                 "service_tier": service_tier,
#    1279                 "stop": stop,
#    1280                 "store": store,
#    1281                 "stream": stream,
#    1282                 "stream_options": stream_options,
#    1283                 "temperature": temperature,
#    1284                 "tool_choice": tool_choice,
#    1285                 "tools": tools,
#    1286                 "top_logprobs": top_logprobs,
#    1287                 "top_p": top_p,
#    1288                 "user": user,
#    1289                 "verbosity": verbosity,
#    1290                 "web_search_options": web_search_options,
#    1291             },
#    1292             completion_create_params.CompletionCreateParamsStreaming
#    1293             if stream
#    1294             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1295         ),
#    1296         options=make_request_options(
#    1297             extra_headers=extra_headers,
#    1298             extra_query=extra_query,
#    1299             extra_body=extra_body,
#    1300             timeout=timeout,
#    1301             security={"bearer_auth": True},
#    1302         ),
#    1303         cast_to=ChatCompletion,
#    1304         stream=stream or False,
#    1305         stream_cls=Stream[ChatCompletionChunk],
#    1306     )
#
# File c:\AI_DataScience_Learning\AI_Engineer_Agentic_Track\.venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\AI_DataScience_Learning\AI_Engineer_Agentic_Track\.venv\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - [{'error': {'code': 400, 'message': 'Please pass a valid API key', 'status': 'INVALID_ARGUMENT'}}]

# %%
print("KEY:", repr(google_api_key))
# Out:
# KEY: None
